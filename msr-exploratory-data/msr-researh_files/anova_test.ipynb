# %%
# ANOVA test

# %%
# https://www.statsmodels.org/stable/anova.html

# %%
import statsmodels.api as sm

# %%
from statsmodels.formula.api import ols

# %%
moore = sm.datasets.get_rdataset("Moore", "carData", cache=True)
# Out:
# /home/andrew/anaconda3/lib/python3.7/site-packages/statsmodels/datasets/utils.py:192: FutureWarning: `item` has been deprecated and will be removed in a future version
#   return dataset_meta["Title"].item()

# %%
data = moore.data

# %%
data = data.rename(columns={"partner.status": "partner_status"})

# %%
data
# Out:
#    partner_status  conformity fcategory  fscore
# 0             low           8       low      37
# 1             low           4      high      57
# 2             low           8      high      65
# 3             low           7       low      20
# 4             low          10       low      36
# 5             low           6       low      18
# 6             low          12    medium      51
# 7             low           4    medium      44
# 8             low          13       low      31
# 9             low          12       low      36
# 10            low           4    medium      42
# 11            low          13      high      56
# 12            low           7       low      28
# 13            low           9    medium      43
# 14            low           9      high      65
# 15            low          24      high      57
# 16            low           6       low      28
# 17            low           7      high      61
# 18            low          23      high      57
# ...

# %%
moore_lm = ols('conformity ~ C(fcategory, Sum)*C(partner_status, Sum)', data=data).fit()

# %%
table = sm.stats.anova_lm(moore_lm, typ=2) # Type 2 ANOVA DataFrame

# %%
moore_lm

# %%
moore_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             conformity   R-squared:                       0.324
# Model:                            OLS   Adj. R-squared:                  0.237
# Method:                 Least Squares   F-statistic:                     3.734
# Date:                Mon, 16 Dec 2019   Prob (F-statistic):            0.00740
# Time:                        16:24:34   Log-Likelihood:                -129.10
# No. Observations:                  45   AIC:                             270.2
# Df Residuals:                      39   BIC:                             281.0
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
table
# Out:
#                                               sum_sq    df          F  \
# C(fcategory, Sum)                          11.614700   2.0   0.276958
# C(partner_status, Sum)                    212.213778   1.0  10.120692
# C(fcategory, Sum):C(partner_status, Sum)  175.488928   2.0   4.184623
# Residual                                  817.763961  39.0        NaN
#
#                                             PR(>F)
# C(fcategory, Sum)                         0.759564
# C(partner_status, Sum)                    0.002874
# C(fcategory, Sum):C(partner_status, Sum)  0.022572
# Residual                                       NaN

# %%
import pandas as pd

# %%
url = 'http://stats191.stanford.edu/data/kidney.table'
kidney_table = pd.read_csv(url, delim_whitespace=True)

# %%
kidney_table["Weight"] = kidney_table["Weight"].map(lambda x: "w" + str(x))

# %%
kidney_table["Duration"] = kidney_table["Duration"].map(lambda x: "d" + str(x))

# %%
kidney_table.head(10)
# Out:
#    Days Duration Weight  ID
# 0   0.0       d1     w1   1
# 1   2.0       d1     w1   2
# 2   1.0       d1     w1   3
# 3   3.0       d1     w1   4
# 4   0.0       d1     w1   5
# 5   2.0       d1     w1   6
# 6   0.0       d1     w1   7
# 7   5.0       d1     w1   8
# 8   6.0       d1     w1   9
# 9   8.0       d1     w1  10

# %%
import numpy as np

# %%
from statsmodels.formula.api import ols
from statsmodels.graphics.api import interaction_plot, abline_plot
from statsmodels.stats.anova import anova_lm

# %%
nosum_lm = ols('np.log(Days+1) ~ C(Duration, Treatment) * C(Weight, Treatment)',
            data=kt).fit()

# %%
nosum_lm

# %%
print(anova_lm(nosum_lm))
# Out:
#                                                df     sum_sq   mean_sq  \
# C(Duration, Treatment)                        1.0   2.339693  2.339693
# C(Weight, Treatment)                          2.0  16.971291  8.485645
# C(Duration, Treatment):C(Weight, Treatment)   2.0   0.635658  0.317829
# Residual                                     54.0  28.989198  0.536837
#
#                                                      F    PR(>F)
# C(Duration, Treatment)                        4.358293  0.041562
# C(Weight, Treatment)                         15.806745  0.000004
# C(Duration, Treatment):C(Weight, Treatment)   0.592040  0.556748
# Residual                                           NaN       NaN
