# %% [markdown]
# # Analyse/Validate Radon "Raw" Results (LOC, etc.)

# %%
import pandas as pd
import numpy as np
import sys
from os.path import join
import altair as alt # Python wrapper for Vega-Lite visualisation grammarimport altair as alt

# %%
DATA_DIR = "../output/"

# %%
raw_df_py2 = pd.read_csv(join(DATA_DIR, "results_radon_raw_python2.csv"))

# %%
raw_df_py3 = pd.read_csv(join(DATA_DIR, "results_radon_raw_python3.csv"))

# %%
raw_df_py2
# Out:
#            repo                                path    loc   lloc   sloc  \
# 0      72225778                 72225778/predict.py  138.0  100.0  113.0
# 1      72225778            72225778/text_cnn_rnn.py   98.0   68.0   69.0
# 2      72225778             72225778/data_helper.py  112.0  100.0   94.0
# 3      72225778                   72225778/train.py  160.0  100.0  123.0
# 4     118248283  118248283/train_speech_commands.py  278.0  193.0  211.0
# ...         ...                                 ...    ...    ...    ...
# 7936   88318858                88318858/batchgen.py  136.0   90.0   86.0
# 7937   88318858                   88318858/train.py  247.0  159.0  166.0
# 7938   40576835          40576835/get_accuracies.py   79.0   55.0   55.0
# 7939   40576835          40576835/api_benchmarks.py  245.0  163.0  187.0
# 7940   40576835                40576835/settings.py   29.0   16.0   16.0
#
#       comments  multi  blank  single_comments  parse_error  internal_error
# 0          2.0    0.0   23.0              2.0        False           False
# 1          9.0    0.0   21.0              8.0        False           False
# 2          3.0    0.0   17.0              1.0        False           False
# 3         12.0    0.0   25.0             12.0        False           False
# 4         12.0    0.0   58.0              9.0        False           False
# ...        ...    ...    ...              ...          ...             ...
# 7936      13.0    3.0   34.0             13.0        False           False
# 7937      51.0    0.0   43.0             38.0        False           False
# 7938       3.0    0.0   21.0              3.0        False           False
# 7939       8.0    0.0   50.0              8.0        False           False
# 7940       6.0    0.0    7.0              6.0        False           False
#
# [7941 rows x 11 columns]

# %%
raw_df_py3
# Out:
#            repo                                path    loc   lloc   sloc  \
# 0      72225778                 72225778/predict.py  138.0  100.0  113.0
# 1      72225778            72225778/text_cnn_rnn.py   98.0   68.0   69.0
# 2      72225778             72225778/data_helper.py  112.0  100.0   94.0
# 3      72225778                   72225778/train.py  160.0  100.0  123.0
# 4     118248283  118248283/train_speech_commands.py  278.0  193.0  211.0
# ...         ...                                 ...    ...    ...    ...
# 7936   88318858                88318858/batchgen.py  136.0   90.0   86.0
# 7937   88318858                   88318858/train.py  247.0  159.0  166.0
# 7938   40576835          40576835/get_accuracies.py   79.0   55.0   55.0
# 7939   40576835          40576835/api_benchmarks.py  245.0  163.0  187.0
# 7940   40576835                40576835/settings.py   29.0   16.0   16.0
#
#       comments  multi  blank  single_comments  parse_error  internal_error
# 0          2.0    0.0   23.0              2.0        False           False
# 1          9.0    0.0   21.0              8.0        False           False
# 2          3.0    0.0   17.0              1.0        False           False
# 3         12.0    0.0   25.0             12.0        False           False
# 4         12.0    0.0   58.0              9.0        False           False
# ...        ...    ...    ...              ...          ...             ...
# 7936      13.0    3.0   34.0             13.0        False           False
# 7937      51.0    0.0   43.0             38.0        False           False
# 7938       3.0    0.0   21.0              3.0        False           False
# 7939       8.0    0.0   50.0              8.0        False           False
# 7940       6.0    0.0    7.0              6.0        False           False
#
# [7941 rows x 11 columns]

# %% [markdown]
# # Self-consistency of LOC calculations

# %% [markdown]
# According to https://radon.readthedocs.io/en/latest/commandline.html#the-raw-command "The equation sloc+multi+singlecomments+blank=loc should always hold."

# %%
target_loc3 = raw_df_py3.sloc + raw_df_py3.multi + raw_df_py3.single_comments + raw_df_py3.blank
target_loc2 = raw_df_py2.sloc + raw_df_py2.multi + raw_df_py2.single_comments + raw_df_py2.blank

# %%
# Should return no results if equation holds
raw_df_py2[(raw_df_py2["loc"] != target_loc2) & ~pd.isnull(raw_df_py2["loc"])]
# Out:
# Empty DataFrame
# Columns: [repo, path, loc, lloc, sloc, comments, multi, blank, single_comments, parse_error, internal_error]
# Index: []

# %%
# Should return no results if equation holds
raw_df_py3[(raw_df_py3["loc"] != target_loc3) & ~pd.isnull(raw_df_py3["loc"])]
# Out:
# Empty DataFrame
# Columns: [repo, path, loc, lloc, sloc, comments, multi, blank, single_comments, parse_error, internal_error]
# Index: []

# %% [markdown]
# # Discrepancies in reported LOC between different Python versions

# %%
all_loc_diffs = (raw_df_py2["loc"] != raw_df_py3["loc"]) & ~(pd.isnull(raw_df_py2["loc"]) & pd.isnull(raw_df_py3["loc"]))
all_loc_diffs_nonull = (raw_df_py2["loc"] != raw_df_py3["loc"]) & ~(pd.isnull(raw_df_py2["loc"]) | pd.isnull(raw_df_py3["loc"]))

# %%
raw_df_py2[all_loc_diffs_nonull]
# Out:
#            repo                                        path    loc   lloc  \
# 15    118248283                 118248283/models/resnext.py  141.0   80.0
# 22     93305304                            93305304/data.py   58.0   39.0
# 23     93305304                            93305304/eval.py   54.0   36.0
# 24     93305304                         93305304/modules.py  289.0  112.0
# 25     93305304                     93305304/hyperparams.py   34.0   21.0
# ...         ...                                         ...    ...    ...
# 7870    1383879        1383879/simplenlp/ja_cabocha/word.py  459.0  350.0
# 7871    1383879  1383879/simplenlp/ja_cabocha/properties.py   48.0   31.0
# 7883   32617150                           32617150/setup.py   24.0    2.0
# 7884   32617150                       32617150/docs/conf.py  357.0   31.0
# 7891   32617150            32617150/simplebayes/__init__.py  307.0  132.0
#
#        sloc  comments  multi  blank  single_comments  parse_error  \
# 15     79.0       0.0   39.0   23.0              0.0        False
# 22     33.0       7.0    4.0   14.0              7.0        False
# 23     31.0       8.0    4.0   12.0              7.0        False
# 24    143.0      12.0  109.0   32.0              5.0        False
# 25     19.0      15.0    4.0    5.0              6.0        False
# ...     ...       ...    ...    ...              ...          ...
# 7870  260.0       3.0   33.0  103.0             63.0        False
# 7871   29.0       0.0    6.0   12.0              1.0        False
# 7883   23.0       0.0    0.0    1.0              0.0        False
# 7884   54.0     218.0    0.0   93.0            210.0        False
# 7891  128.0      19.0  105.0   56.0             18.0        False
#
#       internal_error
# 15             False
# 22             False
# 23             False
# 24             False
# 25             False
# ...              ...
# 7870           False
# 7871           False
# 7883           False
# 7884           False
# 7891           False
#
# [2254 rows x 11 columns]

# %%
raw_df_py3[all_loc_diffs_nonull]
# Out:
#            repo                                        path    loc   lloc  \
# 15    118248283                 118248283/models/resnext.py  142.0   80.0
# 22     93305304                            93305304/data.py   59.0   39.0
# 23     93305304                            93305304/eval.py   55.0   36.0
# 24     93305304                         93305304/modules.py  290.0  112.0
# 25     93305304                     93305304/hyperparams.py   35.0   21.0
# ...         ...                                         ...    ...    ...
# 7870    1383879        1383879/simplenlp/ja_cabocha/word.py  460.0  350.0
# 7871    1383879  1383879/simplenlp/ja_cabocha/properties.py   49.0   31.0
# 7883   32617150                           32617150/setup.py   25.0    2.0
# 7884   32617150                       32617150/docs/conf.py  359.0   31.0
# 7891   32617150            32617150/simplebayes/__init__.py  308.0  132.0
#
#        sloc  comments  multi  blank  single_comments  parse_error  \
# 15     79.0       1.0   39.0   23.0              1.0        False
# 22     33.0       8.0    4.0   14.0              8.0        False
# 23     31.0       9.0    4.0   12.0              8.0        False
# 24    143.0      13.0  109.0   32.0              6.0        False
# 25     19.0      16.0    4.0    5.0              7.0        False
# ...     ...       ...    ...    ...              ...          ...
# 7870  260.0       4.0   33.0  103.0             64.0        False
# 7871   29.0       1.0    6.0   12.0              2.0        False
# 7883   23.0       1.0    0.0    1.0              1.0        False
# 7884   54.0     220.0    0.0   93.0            212.0        False
# 7891  128.0      20.0  105.0   56.0             19.0        False
#
#       internal_error
# 15             False
# 22             False
# 23             False
# 24             False
# 25             False
# ...              ...
# 7870           False
# 7871           False
# 7883           False
# 7884           False
# 7891           False
#
# [2254 rows x 11 columns]

# %% [markdown]
# There are differences between the `loc` calculation in Radon for Python2 versus Radon for Python3.
# The differences seem to occur in files that include `# -*- coding: utf-8 -*-`. In contrast, the `sloc` (Source Lines Of Code) metric seems to be more stable.

# %% [markdown]
# # Discrepancies in reported SLOC

# %%
all_sloc_diffs = (raw_df_py2["sloc"] != raw_df_py3["sloc"]) & ~(pd.isnull(raw_df_py2["sloc"]) & pd.isnull(raw_df_py3["sloc"]))
all_sloc_diffs_nonull = (raw_df_py2["sloc"] != raw_df_py3["sloc"]) & ~(pd.isnull(raw_df_py2["sloc"]) | pd.isnull(raw_df_py3["sloc"]))

# %%
raw_df_py2[all_sloc_diffs]
# Out:
#           repo                                               path     loc  \
# 4372    590142  590142/everything_else/djfrontend/django-1.0.2...   676.0
# 4422  35187829                     35187829/processors/persons.py     NaN
# 4424  35187829                     35187829/processors/attribs.py     NaN
# 4425  35187829                    35187829/processors/entities.py     NaN
# 4437  35187829                        35187829/queries/builtin.py     NaN
# 4439  35187829                     35187829/queries/arithmetic.py     NaN
# 4443  35187829                            35187829/queries/bus.py     NaN
# 4444  35187829                           35187829/queries/wiki.py     NaN
# 4454  35187829                        35187829/utils/cmp_parse.py     NaN
# 4459  35187829                              35187829/utils/cmp.py     NaN
# 4462  35187829                          35187829/utils/tagtest.py     NaN
# 5624   3287642                              3287642/redisbayes.py   231.0
# 7004  20090068                           20090068/src/features.py   141.0
# 7111  61813823                                  61813823/setup.py   128.0
# 7113  61813823                     61813823/pythainlp/__init__.py    37.0
# 7121  61813823                 61813823/pythainlp/tokenize/tcc.py   104.0
# 7141  61813823                    61813823/pythainlp/util/thai.py   146.0
# 7144  61813823               61813823/pythainlp/util/normalize.py   110.0
# 7147  61813823                61813823/pythainlp/util/__init__.py    51.0
# 7148  61813823               61813823/pythainlp/util/wordtonum.py    94.0
# 7274  17856536  17856536/front-end/web2py/site-packages/python...   128.0
# 7486  17856536  17856536/front-end/web2py/gluon/contrib/gatewa...  1332.0
#
#        lloc   sloc  comments  multi  blank  single_comments  parse_error  \
# 4372  451.0  410.0      49.0   92.0  116.0             58.0        False
# 4422    NaN    NaN       NaN    NaN    NaN              NaN         True
# 4424    NaN    NaN       NaN    NaN    NaN              NaN         True
# 4425    NaN    NaN       NaN    NaN    NaN              NaN         True
# 4437    NaN    NaN       NaN    NaN    NaN              NaN         True
# 4439    NaN    NaN       NaN    NaN    NaN              NaN         True
# 4443    NaN    NaN       NaN    NaN    NaN              NaN         True
# 4444    NaN    NaN       NaN    NaN    NaN              NaN         True
# 4454    NaN    NaN       NaN    NaN    NaN              NaN         True
# 4459    NaN    NaN       NaN    NaN    NaN              NaN         True
# 4462    NaN    NaN       NaN    NaN    NaN              NaN         True
# 5624   79.0  136.0      24.0   39.0   32.0             24.0        False
# 7004  114.0  112.0      19.0    0.0   11.0             18.0        False
# 7111    8.0  114.0       1.0    0.0   13.0              1.0        False
# 7113   18.0   23.0      13.0    0.0    8.0              6.0        False
# 7121   34.0   59.0       0.0   28.0   17.0              0.0        False
# 7141   35.0   31.0       0.0   72.0   43.0              0.0        False
# 7144   21.0   52.0       3.0   36.0   22.0              0.0        False
# 7147   14.0   45.0       2.0    3.0    3.0              0.0        False
# 7148   38.0   57.0       6.0   18.0   16.0              3.0        False
# 7274   87.0   85.0      25.0    0.0   18.0             25.0        False
# 7486  882.0  860.0     107.0  152.0  208.0            112.0        False
#
#       internal_error
# 4372           False
# 4422           False
# 4424           False
# 4425           False
# 4437           False
# 4439           False
# 4443           False
# 4444           False
# 4454           False
# 4459           False
# 4462           False
# 5624           False
# 7004           False
# 7111           False
# 7113           False
# 7121           False
# 7141           False
# 7144           False
# 7147           False
# 7148           False
# 7274           False
# 7486           False

# %%
raw_df_py3[all_sloc_diffs]
# Out:
#           repo                                               path     loc  \
# 4372    590142  590142/everything_else/djfrontend/django-1.0.2...     NaN
# 4422  35187829                     35187829/processors/persons.py   501.0
# 4424  35187829                     35187829/processors/attribs.py   159.0
# 4425  35187829                    35187829/processors/entities.py   571.0
# 4437  35187829                        35187829/queries/builtin.py  1133.0
# 4439  35187829                     35187829/queries/arithmetic.py   498.0
# 4443  35187829                            35187829/queries/bus.py   814.0
# 4444  35187829                           35187829/queries/wiki.py   178.0
# 4454  35187829                        35187829/utils/cmp_parse.py   157.0
# 4459  35187829                              35187829/utils/cmp.py  1440.0
# 4462  35187829                          35187829/utils/tagtest.py   250.0
# 5624   3287642                              3287642/redisbayes.py   232.0
# 7004  20090068                           20090068/src/features.py     NaN
# 7111  61813823                                  61813823/setup.py     NaN
# 7113  61813823                     61813823/pythainlp/__init__.py     NaN
# 7121  61813823                 61813823/pythainlp/tokenize/tcc.py     NaN
# 7141  61813823                    61813823/pythainlp/util/thai.py     NaN
# 7144  61813823               61813823/pythainlp/util/normalize.py     NaN
# 7147  61813823                61813823/pythainlp/util/__init__.py     NaN
# 7148  61813823               61813823/pythainlp/util/wordtonum.py     NaN
# 7274  17856536  17856536/front-end/web2py/site-packages/python...     NaN
# 7486  17856536  17856536/front-end/web2py/gluon/contrib/gatewa...     NaN
#
#        lloc    sloc  comments  multi  blank  single_comments  parse_error  \
# 4372    NaN     NaN       NaN    NaN    NaN              NaN         True
# 4422  216.0   285.0      53.0   54.0   94.0             68.0        False
# 4424   58.0    60.0      25.0   27.0   41.0             31.0        False
# 4425  287.0   331.0      81.0   24.0  121.0             95.0        False
# 4437  469.0   732.0     147.0   37.0  197.0            167.0        False
# 4439  171.0   315.0      39.0   20.0  118.0             45.0        False
# 4443  300.0   531.0     104.0   31.0  134.0            118.0        False
# 4444   68.0    92.0      15.0   17.0   49.0             20.0        False
# 4454  121.0   119.0      31.0    0.0   18.0             20.0        False
# 4459  964.0  1171.0     332.0   32.0   99.0            138.0        False
# 4462  165.0   176.0      20.0   17.0   39.0             18.0        False
# 5624   79.0   175.0      25.0    0.0   32.0             25.0        False
# 7004    NaN     NaN       NaN    NaN    NaN              NaN         True
# 7111    NaN     NaN       NaN    NaN    NaN              NaN         True
# 7113    NaN     NaN       NaN    NaN    NaN              NaN         True
# 7121    NaN     NaN       NaN    NaN    NaN              NaN         True
# 7141    NaN     NaN       NaN    NaN    NaN              NaN         True
# 7144    NaN     NaN       NaN    NaN    NaN              NaN         True
# 7147    NaN     NaN       NaN    NaN    NaN              NaN         True
# 7148    NaN     NaN       NaN    NaN    NaN              NaN         True
# 7274    NaN     NaN       NaN    NaN    NaN              NaN         True
# 7486    NaN     NaN       NaN    NaN    NaN              NaN         True
#
#       internal_error
# 4372           False
# 4422           False
# 4424           False
# 4425           False
# 4437           False
# 4439           False
# 4443           False
# 4444           False
# 4454           False
# 4459           False
# 4462           False
# 5624           False
# 7004           False
# 7111           False
# 7113           False
# 7121           False
# 7141           False
# 7144           False
# 7147           False
# 7148           False
# 7274           False
# 7486           False

# %% [markdown]
# Radon appears to be able to calculate raw results on some Python2 files even when run as Python3 (as it just needs to extract the tokens, not build a full AST). However, there were still some cases where the correct version of Python was needed for Radon to extract raw stats for the file.

# %%
raw_df_py2[all_sloc_diffs_nonull]
# Out:
#          repo                   path    loc  lloc   sloc  comments  multi  \
# 5624  3287642  3287642/redisbayes.py  231.0  79.0  136.0      24.0   39.0
#
#       blank  single_comments  parse_error  internal_error
# 5624   32.0             24.0        False           False

# %% [markdown]
# raw_df_py3[all_sloc_diffs_nonull]

# %% [markdown]
# There seems to be one minor difference in whether a comment is treated as a multi-line string between Python2 and Python3 versions of Radon, but otherwise the results are consistent.

# %% [markdown]
# ## Misc

# %% [markdown]
# Confirm that large files processed correctly:

# %%
raw_df_py3[raw_df_py3["path"] == "3546355/preprocess/punkt_data_german.py"]
# Out:
#          repo                                     path      loc  lloc  \
# 1771  3546355  3546355/preprocess/punkt_data_german.py  60318.0   7.0
#
#          sloc  comments  multi  blank  single_comments  parse_error  \
# 1771  60312.0       1.0    0.0    5.0              1.0        False
#
#       internal_error
# 1771           False

# %%
raw_df_py2[raw_df_py2["path"] == "3546355/preprocess/punkt_data_german.py"]
# Out:
#          repo                                     path      loc  lloc  \
# 1771  3546355  3546355/preprocess/punkt_data_german.py  60317.0   7.0
#
#          sloc  comments  multi  blank  single_comments  parse_error  \
# 1771  60312.0       0.0    0.0    5.0              0.0        False
#
#       internal_error
# 1771           False

# %%
raw_df_py3[raw_df_py3["path"] == "15985050/src/feature/ner_PER_list.py"]
# Out:
#           repo                                  path      loc  lloc     sloc  \
# 3687  15985050  15985050/src/feature/ner_PER_list.py  57071.0   1.0  57070.0
#
#       comments  multi  blank  single_comments  parse_error  internal_error
# 3687       1.0    0.0    0.0              1.0        False           False

# %%
raw_df_py2[raw_df_py2["path"] == "15985050/src/feature/ner_PER_list.py"]
# Out:
#           repo                                  path      loc  lloc     sloc  \
# 3687  15985050  15985050/src/feature/ner_PER_list.py  57070.0   1.0  57070.0
#
#       comments  multi  blank  single_comments  parse_error  internal_error
# 3687       0.0    0.0    0.0              0.0        False           False

# %% [markdown]
# (seems fine)
